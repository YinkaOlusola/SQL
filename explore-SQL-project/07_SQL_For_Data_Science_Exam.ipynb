# %% [markdown]
# # SQL for Data Science Examination: TMDb Database
# #### © Explore Data Science Academy

# %% [markdown]
# ## The TMDb Database
#
# In this exam, I explored the [The Movie Database](https://www.themoviedb.org/) - an online movie and TV show database, which houses some of the most popular movies and TV shows at finger tips. The TMDb database supports 39 official languages used in over 180 countries daily, and dates all the way back to 2008.
#
#
# <img src="images/sql_tmdb.jpg" width=80%/>
#
#
# Below is an Entity Relationship diagram(ERD) of the TMDb database:
#
# <img src="images/TMDB_ER_diagram.PNG" width=70%/>
#
# As can be seen from the ER diagram, the TMDb database consists of `12 tables` containing information about movies, cast, genre and so much more.
#
#
#
# #### Getting started!

# %%
import sqlite3
import csv
from sqlalchemy import create_engine
# %load_ext sql_magic

# create engine instance using sqlalchemy
engine = create_engine("sqlite:///data/TMDB.db")
# %config SQL.conn_name = 'engine'

# create connection object using sqlite3
conn = sqlite3.connect('data/TMDB.db')
cursor = conn.cursor()

# %% [markdown]
# <br>
# <br>
#
# #### The query below was used to view all the tables in the database

# %%
# %%read_sql
#
# SELECT name FROM sqlite_master WHERE type IN ('table','view') AND name NOT LIKE 'sqlite_%' ORDER BY 1
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#                     name
# 0    Alan_Rickman_Movies
# 1                 actors
# 2                  casts
# 3               genremap
# 4                 genres
# 5             keywordmap
# 6               keywords
# 7            languagemap
# 8              languages
# 9                 movies
# 10                oscars
# 11   productioncompanies
# 12  productioncompanymap
# 13   productioncountries
# 14  productioncountrymap
# 15           sysdiagrams

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# Who won the Oscar for “Actor in a Leading Role” in 2015? (Hint winner is indicated as '1.0')

# %%
# %%read_sql
#
# SELECT *
# FROM oscars
# WHERE award = 'Actor in a Leading Role'
# AND year = '2015'
# AND winner = '1.0'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    year                    award winner               name          film
# 0  2015  Actor in a Leading Role    1.0  Leonardo DiCaprio  The Revenant

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# What query will produce the ten oldest movies in the database?

# %%
# %%read_sql
#
# SELECT *
# FROM movies
# WHERE release_date IS NOT NULL
# ORDER BY release_date ASC
# LIMIT 10;
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    movie_id                  title                release_date    budget  \
# 0      3059            Intolerance  1916-09-04 00:00:00.000000    385907
# 1      3060         The Big Parade  1925-11-05 00:00:00.000000    245000
# 2        19             Metropolis  1927-01-10 00:00:00.000000  92620000
# 3       905          Pandora's Box  1929-01-30 00:00:00.000000         0
# 4     65203    The Broadway Melody  1929-02-08 00:00:00.000000    379000
# 5     22301          Hell's Angels  1930-11-15 00:00:00.000000   3950000
# 6     22649     A Farewell to Arms  1932-12-08 00:00:00.000000         4
# 7      3062            42nd Street  1933-02-02 00:00:00.000000    439000
# 8     43595     She Done Him Wrong  1933-02-09 00:00:00.000000    200000
# 9      3078  It Happened One Night  1934-02-22 00:00:00.000000    325000
#
#   homepage original_language          original_title  \
# 0     None                en             Intolerance
# 1     None                en          The Big Parade
# 2     None                de              Metropolis
# 3     None                de  Die Bnchse der Pandora
# 4     None                en     The Broadway Melody
# 5     None                en           Hell's Angels
# 6     None                en      A Farewell to Arms
# 7     None                en             42nd Street
# 8     None                en      She Done Him Wrong
# 9     None                en   It Happened One Night
#
#                                             overview  popularity     revenue  \
# 0  The story of a poor young woman, separated by ...    3.232447   8394751.0
# 1  The story of an idle rich boy who joins the US...    0.785744  22000000.0
# 2  In a futuristic city sharply divided between t...   32.351527    650422.0
# 3  The rise and inevitable fall of an amoral but ...    1.824184         0.0
# 4  Harriet and Queenie Mahoney, a vaudeville act,...    0.968865   4358000.0
# 5  Two brothers attending Oxford enlist with the ...    8.484123   8000000.0
# 6  British nurse Catherine Barkley (Helen Hayes) ...    1.199451        25.0
# 7  A producer puts on what may be his last Broadw...    1.933366   2281000.0
# 8  "New York singer and nightclub owner Lady Lou ...    0.622752   2200000.0
# 9  Ellie Andrews has just tied the knot with soci...   11.871424   4500000.0
#
#    runtime release_status                                            tagline  \
# 0    197.0       Released                      The Cruel Hand of Intolerance
# 1    151.0       Released                                               None
# 2    153.0       Released  There can be no understanding between the hand...
# 3    109.0       Released                                               None
# 4    100.0       Released  The pulsating drama of Broadway's bared heart ...
# 5    127.0       Released  Howard Hughes' Thrilling Multi-Million Dollar ...
# 6     89.0       Released          Every woman who has loved will understand
# 7     89.0       Released                                               None
# 8     66.0       Released         Mae West gives a 'Hot Time' to the nation!
# 9    105.0       Released                     TOGETHER... for the first time
#
#    vote_average  vote_count
# 0           7.4          60
# 1           7.0          21
# 2           8.0         657
# 3           7.6          45
# 4           5.0          19
# 5           6.1          19
# 6           6.2          28
# 7           6.1          37
# 8           5.1          27
# 9           7.7         275

# %% [markdown]
# <br>
# <br>
#
# ### Question
# How many unique awards are there in the Oscars table?

# %%
# %%read_sql
#
# SELECT COUNT(DISTINCT award) AS "Number_of_Awards_in_Oscars"
# FROM oscars
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    Number_of_Awards_in_Oscars
# 0                         114

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# How many movies are there that contain the word “Spider” within their title?

# %%
# %%read_sql
#
# SELECT COUNT(DISTINCT movie_id) AS "Number_of_movies_with_Spider_in_Title"
# FROM movies
# WHERE LOWER(title) LIKE '%spider%'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    Number_of_movies_with_Spider_in_Title
# 0                                      9

# %% [markdown]
# <br>
# <br>
#
# ### Question
# How many movies are there that are both in the "Thriller" Genre and contains the word “love” anywhere in the keywords?

# %%
# %%read_sql
#
# SELECT COUNT(m.movie_id) AS "Number_of_Thriller_movies_and_with_love_keyword"
# FROM movies m
# INNER JOIN genremap gm
# ON m.movie_id = gm.movie_id
# INNER JOIN genres g
# ON gm.genre_id = g.genre_id
# INNER JOIN keywordmap km
# ON km.movie_id = m.movie_id
# INNER JOIN keywords k
# ON km.keyword_id = k.keyword_id
# WHERE g.genre_name = 'Thriller'
# AND LOWER(k.keyword_name) LIKE '%love%'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    Number_of_Thriller_movies_and_with_love_keyword
# 0                                               55

# %% [markdown]
# <br>
# <br>
#
# ### Question
# How many movies are there that were released between 1 August 2006 ('2006-08-01') and 1 October 2009 ('2009-10-01') that have a popularity score of more than 40 and a budget of less than 50 000 000?

# %%
# %%read_sql
#
# SELECT COUNT(movie_id) AS "Number_of_movies"
# FROM movies
# WHERE budget < 50000000
# AND popularity > 40
# AND release_date BETWEEN '2006-08-01' AND '2009-10-01'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    Number_of_movies
# 0                29

# %% [markdown]
# <br>
# <br>
#
# ### Question
# How many unique characters has "Vin Diesel" played so far in the database?
#
# Correct answer: 16

# %%
# %%read_sql
#
# SELECT COUNT(DISTINCT c.movie_id), a.actor_name AS "Number_of_unique_characters_played_by_Vin_Diesel"
# FROM casts c
# INNER JOIN actors a
# ON c.actor_id = a.actor_id
# WHERE LOWER(a.actor_name) = 'vin diesel'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    COUNT(DISTINCT c.movie_id) Number_of_unique_characters_played_by_Vin_Diesel
# 0                          19                                       Vin Diesel

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# What are the Genres of the movie “The Royal Tenenbaums”?

# %%
# %%read_sql
#
# SELECT m.title, g.genre_name
# FROM movies m
# INNER JOIN genremap gm
# ON m.movie_id = gm.movie_id
# INNER JOIN genres g
# ON g.genre_id = gm.genre_id
# WHERE title = 'The Royal Tenenbaums'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#                   title genre_name
# 0  The Royal Tenenbaums      Drama
# 1  The Royal Tenenbaums     Comedy

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# What are the three production companies that have the highest movie popularity score on average, as recorded within the database?

# %%
# %%read_sql
#
# SELECT pc.production_company_name, m.movie_id, avg(m.popularity) AS Avg_Popularity
# FROM productioncompanies pc
# INNER JOIN productioncompanymap pcm
# ON pc.production_company_id = pcm.production_company_id
# INNER JOIN movies m
# ON pcm.movie_id = m.movie_id
#
# GROUP BY pc.production_company_name
# ORDER BY [Avg_Popularity] DESC
# LIMIT 3;
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#   production_company_name  movie_id  Avg_Popularity
# 0    The Donners' Company    293660      514.569956
# 1       Bulletproof Cupid    118340      481.098624
# 2           Kinberg Genre    246655      326.920999

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# How many female actors (i.e. gender = 1) have a name that starts with the letter "N"?

# %%
# %%read_sql
#
# SELECT COUNT(DISTINCT actor_id) AS "Number_of_female_actors_with_N_starting_their_names"
# FROM actors
# WHERE gender = 1
# AND LOWER(LTRIM(actor_name)) LIKE 'n%'
# Out:
# Query started at 01:59:58 AM W. Central Africa Standard Time; Query executed in 0.00 m
#    Number_of_female_actors_with_N_starting_their_names
# 0                                                355

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# Which genre has, on average, the lowest movie popularity score?

# %%
# %%read_sql
#
# SELECT g.genre_name AS Genre_Name, avg(m.popularity) AS Avg_Popularity
# FROM genres g
# LEFT JOIN genremap gm
# ON g.genre_id = gm.genre_id
# LEFT JOIN movies m
# ON gm.movie_id = m.movie_id
#
# GROUP BY g.genre_name
# ORDER BY [Avg_Popularity] ASC
# LIMIT 5;
# Out:
# Query started at 01:59:59 AM W. Central Africa Standard Time; Query executed in 0.00 m
#     Genre_Name  Avg_Popularity
# 0      Foreign        0.686787
# 1  Documentary        3.945724
# 2     TV Movie        6.389415
# 3        Music       13.101512
# 4      Romance       15.962426

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# Which award category has the highest number of actor nominations (actors can be male or female)? (Hint `Oscars.name` contains both actors names and film names)
#
# Correct answer: Actor in supporting role

# %%
# %%read_sql
#
# SELECT award AS Award, COUNT(name) AS Number_of_Nominations
# FROM oscars
# GROUP BY Award
# ORDER BY [Number_of_Nominations] DESC
# LIMIT 5;
# Out:
# Query started at 01:59:59 AM W. Central Africa Standard Time; Query executed in 0.00 m
#                           Award  Number_of_Nominations
# 0                     Directing                    429
# 1                  Film Editing                    410
# 2  Actress in a Supporting Role                    400
# 3    Actor in a Supporting Role                    400
# 4   Documentary (Short Subject)                    348

# %% [markdown]
# <br>
# <br>
#
# ### Question
#
# For all of the entries in the Oscars table before 1934, the year is stored differently than in all the subsequent years. E.g the year would be saved as “1932/1933” instead of just “1933” (the second indicated year). Which of the following options would be the appropriate code to update this column to have the format of the year be consistent throughout the entire table (second indicated year only shown)?

# %%
# %%read_sql
#
#
# --Dropping the view if it exists
# DROP VIEW Alan_Rickman_Movies;
# Out:
# Query started at 01:59:59 AM W. Central Africa Standard Time; Query executed in 0.00 m

# %%
# %%read_sql
#
# CREATE VIEW Alan_Rickman_Movies AS
#
# SELECT title, release_date, tagline, overview
# FROM Movies
# LEFT JOIN Casts
# ON Casts.movie_id = Movies.movie_id
# LEFT JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
# Out:
# Query started at 01:59:59 AM W. Central Africa Standard Time; Query executed in 0.00 m

# %% [markdown]
# <br>
# <br>
#
# ### Previous Question continuation
#
# Viewing the created view

# %%
# %%read_sql
#
# SELECT *
# FROM Alan_Rickman_Movies
# Out:
# Query started at 01:59:59 AM W. Central Africa Standard Time; Query executed in 0.00 m
#                                         title                release_date  \
# 0                               Love Actually  2003-09-07 00:00:00.000000
# 1                                    Die Hard  1988-07-15 00:00:00.000000
# 2    Harry Potter and the Philosopher's Stone  2001-11-16 00:00:00.000000
# 3     Harry Potter and the Chamber of Secrets  2002-11-13 00:00:00.000000
# 4    Harry Potter and the Prisoner of Azkaban  2004-05-31 00:00:00.000000
# 5         Harry Potter and the Goblet of Fire  2005-11-05 00:00:00.000000
# 6   Harry Potter and the Order of the Phoenix  2007-06-28 00:00:00.000000
# 7      Harry Potter and the Half-Blood Prince  2009-07-07 00:00:00.000000
# 8                                Galaxy Quest  1999-12-23 00:00:00.000000
# 9            Perfume: The Story of a Murderer  2006-09-13 00:00:00.000000
# 10                            Michael Collins  1996-10-25 00:00:00.000000
# 11                                      Dogma  1999-11-12 00:00:00.000000
# 12                      Sense and Sensibility  1995-12-13 00:00:00.000000
# 13       The Hitchhiker's Guide to the Galaxy  2005-01-15 00:00:00.000000
# 14              Robin Hood: Prince of Thieves  1991-06-14 00:00:00.000000
# 15                         Quigley Down Under  1990-10-17 00:00:00.000000
# 16                        Alice in Wonderland  2010-03-03 00:00:00.000000
# 17                               Bottle Shock  2008-08-06 00:00:00.000000
# 18                                 The Butler  2013-08-16 00:00:00.000000
# 19            Alice Through the Looking Glass  2016-05-25 00:00:00.000000
#
#                                               tagline  \
# 0                       The ultimate romantic comedy.
# 1             40 Stories. Twelve Terrorists. One Cop.
# 2                                Let the Magic Begin.
# 3                        Hogwarts is back in session.
# 4                    Something wicked this way comes.
# 5                 Dark And Difficult Times Lie Ahead.
# 6                            Evil Must Be Confronted.
# 7                               Dark Secrets Revealed
# 8                   A comedy of Galactic Proportions.
# 9                     Based on the best-selling novel
# 10  Ireland, 1916. His Dreams Inspired Hope. His W...
# 11                 It can be Hell getting into Heaven
# 12           Lose your heart and come to your senses.
# 13                      Don't leave Earth without it.
# 14  For the good of all men, and the love of one w...
# 15  There's a price on his head. A girl on his min...
# 16           You're invited to a very important date.
# 17  Based on a true story of love, victory, and fe...
# 18           One quiet voice can ignite a revolution.
# 19                    It's time for a little madness.
#
#                                              overview
# 0   Follows seemingly unrelated people as their li...
# 1   NYPD cop, John McClane's plan to reconcile wit...
# 2   Harry Potter has lived under the stairs at his...
# 3   Ignoring threats to his life, Harry returns to...
# 4   Harry, Ron and Hermione return to Hogwarts for...
# 5   Harry starts his fourth year at Hogwarts, comp...
# 6   Returning for his fifth year of study at Hogwa...
# 7   As Harry begins his sixth year at Hogwarts, he...
# 8   The stars of a 1970s sci-fi show - now scrapin...
# 9   Jean-Baptiste Grenouille, born in the stench o...
# 10  Michael Collins plays a crucial role in the es...
# 11  The latest battle in the eternal war between G...
# 12  Rich Mr. Dashwood dies, leaving his second wif...
# 13  "Mere seconds before the Earth is to be demoli...
# 14  When the dastardly Sheriff of Nottingham murde...
# 15  American Matt Quigley answers Australian land ...
# 16  Alice, an unpretentious and individual 19-year...
# 17  Paris-based wine expert Steven Spurrier heads ...
# 18  A look at the life of Cecil Gaines who served ...
# 19  "In the sequel to Tim Burton's ""Alice in Wond...
